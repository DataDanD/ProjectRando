# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/d/Documents/Class/Other/project/CompleteDataset.csv')
# Out:
# /Users/d/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (23,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df = df.drop(['Photo','Flag','Club Logo'],axis=1)

# %%
df.shape
# Out:
# (17981, 72)

# %%
df['Positions'] = df['Preferred Positions'].str.split('\s+').str[0]
set(df['Positions'])
colors = {
 'CAM': 'green',
 'CB': 'Yellow',
 'CDM': 'green',
 'CF': 'blue',
 'CM': 'green',
 'GK': 'Orange',
 'LB': 'Yellow',
 'LM': 'green',
 'LW': 'blue',
 'LWB': 'Yellow',
 'RB': 'Yellow',
 'RM': 'green',
 'RW': 'blue',
 'RWB': 'Yellow',
 'ST': 'blue'}

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Age', 'Nationality', 'Overall', 'Potential',
#        'Club', 'Value', 'Wage', 'Special', 'Acceleration', 'Aggression',
#        'Agility', 'Balance', 'Ball control', 'Composure', 'Crossing', 'Curve',
#        'Dribbling', 'Finishing', 'Free kick accuracy', 'GK diving',
#        'GK handling', 'GK kicking', 'GK positioning', 'GK reflexes',
#        'Heading accuracy', 'Interceptions', 'Jumping', 'Long passing',
#        'Long shots', 'Marking', 'Penalties', 'Positioning', 'Reactions',
#        'Short passing', 'Shot power', 'Sliding tackle', 'Sprint speed',
#        'Stamina', 'Standing tackle', 'Strength', 'Vision', 'Volleys', 'CAM',
#        'CB', 'CDM', 'CF', 'CM', 'ID', 'LAM', 'LB', 'LCB', 'LCM', 'LDM', 'LF',
#        'LM', 'LS', 'LW', 'LWB', 'Preferred Positions', 'RAM', 'RB', 'RCB',
#        'RCM', 'RDM', 'RF', 'RM', 'RS', 'RW', 'RWB', 'ST'],
#       dtype='object')

# %%
performance = ['Name', 'Age','Overall', 'Potential', 'Club', 'Value', 'Wage', 'Special', 'Acceleration', 'Aggression',
               'Agility', 'Balance', 'Ball control', 'Composure', 'Crossing', 'Curve', 'Dribbling', 'Finishing', 
               'Free kick accuracy', 'Heading accuracy', 'Interceptions', 'Jumping', 'Long passing', 'Long shots', 
               'Marking', 'Penalties', 'Positioning', 'Reactions', 'Short passing', 'Shot power', 'Sliding tackle', 
               'Sprint speed', 'Stamina', 'Standing tackle', 'Strength', 'Vision', 'Volleys','Preferred Positions']

# %%
GK = ['Name','Nationality','Club', 'Value','GK diving', 'GK handling', 'GK kicking', 'GK positioning', 'GK reflexes',
      'Preferred Positions', 'Overall']

# %%
Player = ['Special', 'Acceleration', 'Aggression', 'Agility', 'Balance', 'Ball control', 'Composure', 'Crossing', 
          'Curve', 'Dribbling', 'Finishing', 'Free kick accuracy','Heading accuracy', 'Interceptions', 'Jumping', 
          'Long passing', 'Long shots', 'Marking', 'Penalties', 'Positioning', 'Reactions', 'Short passing', 
          'Shot power', 'Sliding tackle', 'Sprint speed', 'Stamina', 'Standing tackle', 'Strength', 'Vision', 'Volleys']

# %%
fdf = df[performance]
gkdf = df[GK]

# %%
fdf.columns
# Out:
# Index(['Name', 'Age', 'Overall', 'Potential', 'Club', 'Value', 'Wage',
#        'Special', 'Acceleration', 'Aggression', 'Agility', 'Balance',
#        'Ball control', 'Composure', 'Crossing', 'Curve', 'Dribbling',
#        'Finishing', 'Free kick accuracy', 'Heading accuracy', 'Interceptions',
#        'Jumping', 'Long passing', 'Long shots', 'Marking', 'Penalties',
#        'Positioning', 'Reactions', 'Short passing', 'Shot power',
#        'Sliding tackle', 'Sprint speed', 'Stamina', 'Standing tackle',
#        'Strength', 'Vision', 'Volleys', 'Preferred Positions'],
#       dtype='object')

# %%
fdf = fdf[fdf['Preferred Positions'] != 'GK ']
fdf.max(), fdf.min()
#Make max dictinary with [Name, Nationality, Overall, Preferred Positions]
#Git rid of goalies
# Out:
# (Name                   Óscar Plano
#  Age                             41
#  Overall                         94
#  Potential                       94
#  Value                          €9M
#  Wage                           €9K
#  Special                       2291
#  Acceleration                    96
#  Aggression                      96
#  Agility                         96
#  Balance                         96
#  Ball control                    95
#  Composure                       96
#  Crossing                        91
#  Curve                           92
#  Dribbling                       97
#  Finishing                       95
#  Heading accuracy                94
#  Interceptions                   92
#  Jumping                         95
#  Long passing                    93
#  Long shots                      92
#  Marking                         92
#  Positioning                     95
#  Reactions                       96
#  Short passing                   92
# ...

# %%
gkdf.max()
#GoalKeeper shotouts
# Out:
# Name                   Óscar Whalley
# Nationality                    Wales
# Value                            €9M
# GK diving                         91
# GK handling                       91
# GK kicking                        95
# GK positioning                    91
# GK reflexes                       90
# Preferred Positions              GK
# Overall                           92
# dtype: object

# %%
#Primer League | MLS | USA

# %%
# gkdf[gkdf['GK diving'] > 91.0]
gkdf = gkdf.convert_objects(convert_numeric=True)
gkdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17981 entries, 0 to 17980
# Data columns (total 11 columns):
# Name                   17981 non-null object
# Nationality            17981 non-null object
# Club                   17733 non-null object
# Value                  17981 non-null object
# GK diving              17955 non-null float64
# GK handling            17954 non-null float64
# GK kicking             17962 non-null float64
# GK positioning         17955 non-null float64
# GK reflexes            17952 non-null float64
# Preferred Positions    17981 non-null object
# Overall                17981 non-null int64
# dtypes: float64(5), int64(1), object(5)
# memory usage: 1.5+ MB
# /Users/d/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.

# %%
gkdf[gkdf['GK diving'] >= 85]
# Out:
#               Name Nationality                    Club   Value  GK diving  \
# 4         M. Neuer     Germany        FC Bayern Munich    €61M       91.0
# 6           De Gea       Spain       Manchester United  €64.5M       90.0
# 12     T. Courtois     Belgium                 Chelsea    €59M       85.0
# 18       G. Buffon       Italy                Juventus   €4.5M       89.0
# 29       H. Lloris      France       Tottenham Hotspur    €38M       88.0
# 43   S. Handanovič    Slovenia                   Inter    €29M       87.0
# 74        K. Navas  Costa Rica          Real Madrid CF  €24.5M       87.0
# 77         B. Leno     Germany     Bayer 04 Leverkusen    €34M       85.0
# 117  Sergio Asenjo       Spain           Villarreal CF    €25M       86.0
# 131       G. Rulli   Argentina           Real Sociedad  €25.5M       85.0
# 148       A. Lopes    Portugal      Olympique Lyonnais  €22.5M       86.0
# 174   Rui Patrício    Portugal             Sporting CP  €17.5M       85.0
# ...

# %%
# fig = plt.subplot(figsize=(20,20))
plt.scatter(gkdf['GK diving'],gkdf['GK handling'])
# c=gkdf['Preferred Positions']
# s=None, c=None, marker=None, cmap=None, norm=None, vmin=None, vmax=None, alpha=None, linewidths=None, 
# verts=None, edgecolors=None, hold=None, data=None,
#Color by position
plt.show()

# %%
gkdf = gkdf[gkdf['Preferred Positions'] == 'GK ']

# %%
plt.scatter(gkdf['GK diving'],gkdf['GK handling'])
plt.show()

# %%
plt.scatter(gkdf['GK handling'],gkdf['GK kicking'])
plt.show()

# %%
print(gkdf.corr().sum()/6)
gkdf.corr()
# Out:
# GK diving         0.844499
# GK handling       0.835706
# GK kicking        0.744265
# GK positioning    0.844094
# GK reflexes       0.846321
# Overall           0.907898
# dtype: float64
#                 GK diving  GK handling  GK kicking  GK positioning  \
# GK diving        1.000000     0.788606    0.666441        0.798565
# GK handling      0.788606     1.000000    0.688453        0.843613
# GK kicking       0.666441     0.688453    1.000000        0.687356
# GK positioning   0.798565     0.843613    0.687356        1.000000
# GK reflexes      0.885677     0.783646    0.671925        0.806680
# Overall          0.927705     0.909920    0.751415        0.928352
#
#                 GK reflexes   Overall
# GK diving          0.885677  0.927705
# GK handling        0.783646  0.909920
# GK kicking         0.671925  0.751415
# GK positioning     0.806680  0.928352
# GK reflexes        1.000000  0.929998
# Overall            0.929998  1.000000

# %%
fdf.axes
# Out:
# [Int64Index([    0,     1,     2,     3,     5,     7,     8,     9,    10,
#                 11,
#              ...
#              17969, 17970, 17971, 17972, 17973, 17974, 17975, 17978, 17979,
#              17980],
#             dtype='int64', length=15952),
#  Index(['Name', 'Age', 'Overall', 'Potential', 'Club', 'Value', 'Wage',
#         'Special', 'Acceleration', 'Aggression', 'Agility', 'Balance',
#         'Ball control', 'Composure', 'Crossing', 'Curve', 'Dribbling',
#         'Finishing', 'Free kick accuracy', 'Heading accuracy', 'Interceptions',
#         'Jumping', 'Long passing', 'Long shots', 'Marking', 'Penalties',
#         'Positioning', 'Reactions', 'Short passing', 'Shot power',
#         'Sliding tackle', 'Sprint speed', 'Stamina', 'Standing tackle',
#         'Strength', 'Vision', 'Volleys', 'Preferred Positions'],
#        dtype='object')]

# %%
fdf.corr()
# Out:
#                 Age   Overall  Potential   Special
# Age        1.000000  0.462062  -0.228583  0.418046
# Overall    0.462062  1.000000   0.675489  0.796030
# Potential -0.228583  0.675489   1.000000  0.489016
# Special    0.418046  0.796030   0.489016  1.000000

# %%
numbers =['Overall', 'Acceleration', 'Aggression', 'Agility', 'Balance',
        'Ball control', 'Composure', 'Crossing', 'Curve', 'Dribbling',
        'Finishing', 'Free kick accuracy', 'Heading accuracy', 'Interceptions',
        'Jumping', 'Long passing', 'Long shots', 'Marking', 'Penalties',
        'Positioning', 'Reactions', 'Short passing', 'Shot power',
        'Sliding tackle', 'Sprint speed', 'Stamina', 'Standing tackle',
        'Strength', 'Vision', 'Volleys', 'Preferred Positions']
ffdf = fdf[numbers]

Attack =['Overall', 'Acceleration', 'Aggression', 'Agility', 'Balance',
        'Ball control', 'Composure', 'Crossing', 'Curve', 'Dribbling',
        'Finishing', 'Free kick accuracy', 'Heading accuracy', 'Interceptions',
        'Jumping', 'Long passing', 'Long shots','Penalties',
        'Positioning', 'Reactions', 'Short passing', 'Shot power',
        'Sprint speed', 'Stamina',
        'Strength', 'Vision', 'Volleys', 'Preferred Positions']
adf = fdf[Attack]
adf = adf.convert_objects(convert_numeric=True)
defend =['Overall', 'Acceleration', 'Aggression', 'Agility', 'Balance',
        'Ball control', 'Composure', 'Dribbling', 'Interceptions',
        'Jumping', 'Long passing', 'Marking',
        'Positioning', 'Reactions', 'Short passing',
        'Sliding tackle', 'Sprint speed', 'Stamina', 'Standing tackle',
        'Strength', 'Vision', 'Volleys', 'Preferred Positions']
dedf = fdf[Attack]
dedf = dedf.convert_objects(convert_numeric=True)
# Out:
# /Users/d/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:18: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
# /Users/d/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:26: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.

# %%
ffdf = ffdf.convert_objects(convert_numeric=True)
ffdf.info()
# Out:
# /Users/d/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15952 entries, 0 to 17980
# Data columns (total 31 columns):
# Overall                15952 non-null int64
# Acceleration           15872 non-null float64
# Aggression             15885 non-null float64
# Agility                15885 non-null float64
# Balance                15899 non-null float64
# Ball control           15814 non-null float64
# Composure              15860 non-null float64
# Crossing               15856 non-null float64
# Curve                  15879 non-null float64
# Dribbling              15822 non-null float64
# Finishing              15839 non-null float64
# Free kick accuracy     15904 non-null float64
# Heading accuracy       15877 non-null float64
# ...

# %%
ffdf.corr()
# Out:
#                      Overall  Acceleration  Aggression   Agility   Balance  \
# Overall             1.000000      0.171682    0.457879  0.251339  0.061221
# Acceleration        0.171682      1.000000   -0.207365  0.718374  0.582060
# Aggression          0.457879     -0.207365    1.000000 -0.160237 -0.199127
# Agility             0.251339      0.718374   -0.160237  1.000000  0.705274
# Balance             0.061221      0.582060   -0.199127  0.705274  1.000000
# Ball control        0.704506      0.380392    0.122749  0.547414  0.364343
# Composure           0.775944      0.102180    0.360223  0.248695  0.100922
# Crossing            0.498350      0.430927    0.105064  0.543052  0.435097
# Curve               0.501637      0.361496    0.032645  0.532906  0.396655
# Dribbling           0.493546      0.554793   -0.071394  0.662223  0.497641
# Finishing           0.362688      0.368910   -0.200941  0.475281  0.302997
# ...

# %%
plt.scatter(ffdf['Balance'], ffdf['Heading accuracy'],alpha=.5,c=colors)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-96-970ddb17dcc2> in <module>()
# ----> 1 plt.scatter(ffdf['Balance'], ffdf['Heading accuracy'],alpha=.5)
#       2 plt.show()
#
# /Users/d/anaconda/lib/python3.6/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3432                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3433                          linewidths=linewidths, verts=verts,
# -> 3434                          edgecolors=edgecolors, data=data, **kwargs)
#    3435     finally:
#    3436         ax._hold = washold
#
# /Users/d/anaconda/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
# ...

# %%
dedf.corr()
# Out:
#                      Overall  Acceleration  Aggression   Agility   Balance  \
# Overall             1.000000      0.171682    0.457879  0.251339  0.061221
# Acceleration        0.171682      1.000000   -0.207365  0.718374  0.582060
# Aggression          0.457879     -0.207365    1.000000 -0.160237 -0.199127
# Agility             0.251339      0.718374   -0.160237  1.000000  0.705274
# Balance             0.061221      0.582060   -0.199127  0.705274  1.000000
# Ball control        0.704506      0.380392    0.122749  0.547414  0.364343
# Composure           0.775944      0.102180    0.360223  0.248695  0.100922
# Crossing            0.498350      0.430927    0.105064  0.543052  0.435097
# Curve               0.501637      0.361496    0.032645  0.532906  0.396655
# Dribbling           0.493546      0.554793   -0.071394  0.662223  0.497641
# Finishing           0.362688      0.368910   -0.200941  0.475281  0.302997
# ...

# %%
short pass long pass
long shot shot power
long shot long pass
reactions and overall

# %%
arsenal vs newcastle
# Out:
# numpy.ndarray
